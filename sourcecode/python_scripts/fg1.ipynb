# %%
import Video_List_Interface

# %%
fg = Video_List_Interface.VideoListInterface()
# Out:
# Reading from the Internal CSV File

# %%
fg.cal_Display()
# Out:
#   VIDEO Name VIDEO Discription  Raw VIDEO Present  \
# 0         1a               aaa               True
# 1         2b               bbb               True
# 2         3c               ccc              False
# 3         4d               ddd               True
# 4         5e               eee               True
#
#    ContaingFrameNumber VIDEO Present
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False

# %%
fg.cal_Insert_All_Raw_Video_Files('''Your Input Video Files''')

# %%
fg.cal_Display()
# Out:
#   VIDEO Name VIDEO Discription  Raw VIDEO Present  \
# 0         1a               aaa               True
# 1         2b               bbb               True
# 2         3c               ccc              False
# 3         4d               ddd               True
# 4         5e               eee               True
#
#    ContaingFrameNumber VIDEO Present
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False

# %%
fg.cal_Read_Data_From_File_And_Trim('''Your File Location''')
